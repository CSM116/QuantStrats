# %%
import yfinance as yf
import pandas as pd
from datetime import date

# List of Dow Jones (DJIA) constituents
tickers = [
    "AAPL", "AMGN", "AXP", "BA", "CAT", "CSCO", "CVX", "DIS", "DOW", "GS",
    "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KO", "MCD", "MMM", "MRK",
    "MSFT", "NKE", "PG", "TRV", "UNH", "V", "VZ", "WBA", "WMT"
]

# Define the date range
from_date = date(1928, 1, 1) 
to_date = date.today()

# Download historical data
data = yf.download(tickers, from_date, to_date, interval="1d", auto_adjust=False)
data = data.swaplevel(axis=1)
# Save to CSV
# data.to_csv("DJIA_Historical_Data.csv")

# Display the first few rows
display(data.head())
# Out:
# [*********************100%***********************]  29 of 29 completed
# Ticker          AAPL      AMGN       AXP        BA       CAT      CSCO  \
# Price      Adj Close Adj Close Adj Close Adj Close Adj Close Adj Close
# Date
# 1962-01-02       NaN       NaN       NaN  0.190931  0.469587       NaN
# 1962-01-03       NaN       NaN       NaN  0.194750  0.474160       NaN
# 1962-01-04       NaN       NaN       NaN  0.192840  0.486358       NaN
# 1962-01-05       NaN       NaN       NaN  0.189022  0.490932       NaN
# 1962-01-08       NaN       NaN       NaN  0.189499  0.493981       NaN
#
# Ticker           CVX       DIS       DOW        GS  ...      MRK   MSFT  \
# Price      Adj Close Adj Close Adj Close Adj Close  ...   Volume Volume
# Date                                                ...
# 1962-01-02  0.321829  0.057686       NaN       NaN  ...   633830    NaN
# 1962-01-03  0.321103  0.058460       NaN       NaN  ...  6564672    NaN
# ...

# %%
data.loc[:, pd.IndexSlice[:, ['Adj Close']]]
# Out:
# Ticker            AAPL        AMGN         AXP          BA         CAT  \
# Price        Adj Close   Adj Close   Adj Close   Adj Close   Adj Close
# Date
# 1962-01-02         NaN         NaN         NaN    0.190931    0.469587
# 1962-01-03         NaN         NaN         NaN    0.194750    0.474160
# 1962-01-04         NaN         NaN         NaN    0.192840    0.486358
# 1962-01-05         NaN         NaN         NaN    0.189022    0.490932
# 1962-01-08         NaN         NaN         NaN    0.189499    0.493981
# ...                ...         ...         ...         ...         ...
# 2025-03-03  238.029999  310.779999  295.489990  170.059998  332.040009
# 2025-03-04  235.929993  312.190002  283.470001  158.899994  326.750000
# 2025-03-05  235.740005  316.570007  284.179993  163.160004  338.489990
# 2025-03-06  235.330002  317.820007  275.640015  158.429993  341.010010
# 2025-03-07  239.070007  324.859985  273.209991  154.179993  350.299988
#
# ...
